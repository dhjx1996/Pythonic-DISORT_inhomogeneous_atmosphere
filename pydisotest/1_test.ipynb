# %%
import PythonicDISORT
from PythonicDISORT.subroutines import _compare
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from math import pi

# %% [markdown]
# Previously saved reference solutions will be loaded if F2PY-wrapped Stamnes' DISORT is unavailable.

# %%
disort_is_installed = True
try:
    import disort
    print("Stamnes' DISORT imported.")
except ImportError:
    disort_is_installed = False
    print("Stamnes' DISORT unavailable. Cached results will be used.")
# Out:
# Stamnes' DISORT unavailable. Cached results will be used.

# %% [markdown]
# # Table of Contents
# * [1a and setup](#1a-and-setup)
# * [1b](#1b)
# * [1c](#1c)
# * [1d](#1d)
# * [1e](#1e)

# %% [markdown]
# # Test Problem 1:  Isotropic Scattering

# %% [markdown]
# The *isotropic phase function* is a simple way to model diffusion-like radiative transfer. Consequently, it should be paired with thick (large `tau_arr`) and conservative (`omega_arr` close to 1) atmospheres, though the test problems are not intended to serve as realistic models. The isotropic phase function is also the simplest possible phase function with its only non-zero Legendre coefficient being its zeroth coefficient which equals $1$, but that is true of every phase function. These problems are thus the simplest multiple scattering problems on which to test PythonicDISORT. Note that when the single-scattering albedo `omega_arr` is small, e.g. in problem 1d, the solution is approximately that of single-scattering (this is true irrespective of the phase function). This is useful because 1D single-scattering problems can be solved analytically and so provide a baseline for comparison.
#
# Results can be compared to Table 12 of Van de Hulst, H.C., 1980: *Multiple Light Scattering, Tables, Formulas and Applications*, Volume 1, Academic Press, New York. The intensity field of the upwelling radiation, which can be compared to satellite measurements, is plotted for each subproblem.

# %% [markdown]
# # 1a and setup

# %% [markdown]
# **PythonicDISORT**

# %%
######################################### PYDISORT ARGUMENTS #######################################

tau_arr = 0.03125  # One layer of thickness 0.03125 (very thin atmosphere)
omega_arr = 0.2  # 20% of light is scattered each interaction (very highly absorbing medium)
NQuad = 16  # 16 streams (8 quadrature nodes for each hemisphere)
Leg_coeffs_all = np.zeros(17)
Leg_coeffs_all[0] = 1  # Isotropic phase function
mu0 = 0.1  # Cosine of solar zenith angle (low, glancing angle)
I0 = pi / mu0  # Intensity of direct beam
phi0 = pi  # Azimuthal angle of direct beam

# Optional (used)

# Optional (unused)
NLeg = None
NFourier = None
b_pos = 0
b_neg = 0
only_flux = False
f_arr = 0
NT_cor = False
BDRF_Fourier_modes = []
s_poly_coeffs = np.array([[]])
use_banded_solver_NLayers = 10
autograd_compatible=False

####################################################################################################

# %%
# Call pydisort function
mu_arr, flux_up, flux_down, u0, u = PythonicDISORT.pydisort(
    tau_arr, omega_arr,
    NQuad,
    Leg_coeffs_all,
    mu0, I0, phi0,
)

# %% [markdown]
# **Setup for tests**

# %%
# Reorder mu_arr from smallest to largest
reorder_mu = np.argsort(mu_arr)
mu_arr_RO = mu_arr[reorder_mu]

# We may not want to compare intensities around the direct beam
deg_around_beam_to_not_compare = 0
mu_to_compare = (
    np.abs(np.arccos(np.abs(mu_arr_RO)) - np.arccos(mu0)) * 180 / pi
    > deg_around_beam_to_not_compare
)
mu_test_arr_RO = mu_arr_RO[mu_to_compare]

# %%
# Number of phi grid points
Nphi = 2
phi_arr = np.random.random(Nphi) * 2 * pi

# tau test points
tau_test_arr = np.array([0, 0.03125])
Ntau = len(tau_test_arr)

# %% [markdown]
# **Stamnes' DISORT**

# %%
# Stamnes' DISORT arguments
nlyr = 1
nmom = NQuad
nstr = NQuad
numu = NQuad
nphi = Nphi
ntau = Ntau
usrang = True
usrtau = True
ibcnd = 0
onlyfl = False
prnt = np.array([False, False, False, False, False])  # Prints to CMD instead of this notebook
plank = False
lamber = True
deltamplus = False
do_pseudo_sphere = False
dtauc = tau_arr
ssalb = omega_arr
pmom = Leg_coeffs_all.T
temper = np.zeros(nlyr + 1)
wvnmlo = 0
wvnmhi = 0
utau = tau_test_arr
umu0 = mu0
phi0 = phi0
umu = mu_arr_RO
phi = phi_arr
fbeam = I0
fisot = 0
albedo = 0
btemp = 0
ttemp = 0
temis = 0
earth_radius = 6371
h_lyr = np.zeros(nlyr + 1)
rhoq = np.zeros((nstr // 2, nstr + 1, nstr))
rhou = np.zeros((numu, nstr // 2 + 1, nstr))
rho_accurate = np.zeros((numu, nphi))
bemst = np.zeros(nstr // 2)
emust = np.zeros(numu)
accur = 0
header = ""
rfldir = np.zeros(ntau)
rfldn = np.zeros(ntau)
flup = np.zeros(ntau)
dfdt = np.zeros(ntau)
uavg = np.zeros(ntau)
uu = np.zeros((numu, ntau, nphi))
albmed = np.zeros(numu)
trnmed = np.zeros(numu)

# %%
if disort_is_installed:
    # Run disort, putting DFDT, UAVG, and UU in a, b, and c, respectively
    rfldir, rfldn, flup, dfdt, uavg, uu, albmed, trnmed = disort.disort(usrang, usrtau, ibcnd, onlyfl, prnt, plank, lamber, deltamplus, do_pseudo_sphere, dtauc, ssalb,
                            pmom, temper, wvnmlo, wvnmhi, utau, umu0, phi0 * 180/pi, umu, phi * 180/pi, fbeam, fisot, albedo, btemp, ttemp,
                            temis, earth_radius, h_lyr, rhoq, rhou, rho_accurate, bemst, emust, accur, header, rfldir,
                            rfldn, flup, dfdt, uavg, uu, albmed, trnmed)
    results = {
        "uu": uu,
        "flup": flup,
        "rfldn": rfldn,
        "rfldir": rfldir,
        "tau_test_arr": tau_test_arr,
        "phi_arr": phi_arr
    }
else:
    # Load saved results from Stamnes' DISORT
    results = np.load("Stamnes_results/1a_test.npz")

# %% [markdown]
# **Comparisons**

# %%
(
    diff_flux_up,
    ratio_flux_up,
    diff_flux_down_diffuse,
    ratio_flux_down_diffuse,
    diff_flux_down_direct,
    ratio_flux_down_direct,
    diff,
    diff_ratio,
) = _compare(results, mu_to_compare, reorder_mu, flux_up, flux_down, u)
# Out:
# Max pointwise differences
#
# Upward (diffuse) fluxes
# Difference = 4.989720242465484e-09
# Difference ratio = 6.056479082481458e-08
#
# Downward (diffuse) fluxes
# Difference = 3.974040721499428e-09
# Difference ratio = 5.004408911664391e-08
#
# Direct (downward) fluxes
# Difference = 2.1294565577534286e-07
# Difference ratio = 9.264798488614142e-08
#
# Intensities
#
# At tau = 0.03125
# Max pointwise difference = 8.556747373988927e-07
# At tau = 0.03125
# Max pointwise difference ratio = 7.486806882496865e-06

# %% [markdown]
# **Does the test pass?**

# %%
assert np.max(ratio_flux_up[diff_flux_up > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_diffuse[diff_flux_down_diffuse > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_direct[diff_flux_down_direct > 1e-3], initial=0) < 1e-3
assert np.max(diff_ratio[diff > 1e-3], initial=0) < 1e-2

'''np.savez_compressed (
    "Stamnes_results/1a_test",
    phi_arr=phi_arr,
    tau_test_arr=tau_test_arr,
    uu=uu,
    flup=flup,
    rfldn=rfldn,
    rfldir=rfldir,
)'''

print("The test passes")
# Out:
# The test passes

# %% [markdown]
# **Plots**

# %%
Nphi_plot = int((NQuad * pi) // 2) * 2 + 1
phi_arr_plot, full_weights_phi = PythonicDISORT.subroutines.Clenshaw_Curtis_quad(Nphi_plot)

MU_ARR, PHI_ARR = np.meshgrid(phi_arr_plot, mu_arr[:NQuad // 2])

# %%
plot = u(0, phi_arr_plot)[:NQuad // 2]

fig, ax = plt.subplots(figsize=(9, 6), subplot_kw={"projection": "polar"})

_cf = ax.contourf(MU_ARR, PHI_ARR, plot)
ax.plot(phi0, mu0, "o", color="red", label="Direct beam")

ax.set_rlim(1.0, 0.0)

ax.set_xlabel(r"$\phi$")
#ax.set_ylabel(r"$\mu$")
ax.text(1, 0.75, r"$\mu$", transform=ax.transAxes,
        rotation=0, ha="center", va="center")
fig.colorbar(_cf, ax=ax, pad=0.10)
ax.set_title("Upward intensity field at top of atmosphere")
ax.legend()
plt.show()

# %% [markdown]
# ----------

# %% [markdown]
# # 1b

# %% [markdown]
# **PythonicDISORT**

# %%
######################################### PYDISORT ARGUMENTS #######################################

tau_arr = 0.03125
omega_arr = 1 - 1e-6  # Reduced from 1 (conservative scattering) which is not implemented
NQuad = 16
Leg_coeffs_all = np.zeros(17)
Leg_coeffs_all[0] = 1
mu0 = 0.1
I0 = pi / mu0
phi0 = pi

# Optional (used)

# Optional (unused)
NLeg=None
NFourier=None
b_pos=0
b_neg=0
only_flux=False
f_arr=0
NT_cor=False
BDRF_Fourier_modes=[]
s_poly_coeffs=np.array([[]])
use_banded_solver_NLayers=10
autograd_compatible=False

####################################################################################################

# %%
# Call pydisort function
mu_arr, flux_up, flux_down, u0, u = PythonicDISORT.pydisort(
    tau_arr, omega_arr,
    NQuad,
    Leg_coeffs_all,
    mu0, I0, phi0,
)

# %% [markdown]
# **Stamnes' DISORT**

# %%
# tau test points
tau_test_arr = np.array([0, 0.03125])
Ntau = len(tau_test_arr)

# %%
# Stamnes' DISORT arguments
nlyr = 1
nmom = NQuad
nstr = NQuad
numu = NQuad
nphi = Nphi
ntau = Ntau
usrang = True
usrtau = True
ibcnd = 0
onlyfl = False
prnt = np.array([False, False, False, False, False])  # Prints to CMD instead of this notebook
plank = False
lamber = True
deltamplus = False
do_pseudo_sphere = False
dtauc = tau_arr
ssalb = omega_arr
pmom = Leg_coeffs_all.T
temper = np.zeros(nlyr + 1)
wvnmlo = 0
wvnmhi = 0
utau = tau_test_arr
umu0 = mu0
phi0 = phi0
umu = mu_arr_RO
phi = phi_arr
fbeam = I0
fisot = 0
albedo = 0
btemp = 0
ttemp = 0
temis = 0
earth_radius = 6371
h_lyr = np.zeros(nlyr + 1)
rhoq = np.zeros((nstr // 2, nstr + 1, nstr))
rhou = np.zeros((numu, nstr // 2 + 1, nstr))
rho_accurate = np.zeros((numu, nphi))
bemst = np.zeros(nstr // 2)
emust = np.zeros(numu)
accur = 0
header = ""
rfldir = np.zeros(ntau)
rfldn = np.zeros(ntau)
flup = np.zeros(ntau)
dfdt = np.zeros(ntau)
uavg = np.zeros(ntau)
uu = np.zeros((numu, ntau, nphi))
albmed = np.zeros(numu)
trnmed = np.zeros(numu)

# %%
if disort_is_installed:
    # Run disort, putting DFDT, UAVG, and UU in a, b, and c, respectively
    rfldir, rfldn, flup, dfdt, uavg, uu, albmed, trnmed = disort.disort(usrang, usrtau, ibcnd, onlyfl, prnt, plank, lamber, deltamplus, do_pseudo_sphere, dtauc, ssalb,
                            pmom, temper, wvnmlo, wvnmhi, utau, umu0, phi0 * 180/pi, umu, phi * 180/pi, fbeam, fisot, albedo, btemp, ttemp,
                            temis, earth_radius, h_lyr, rhoq, rhou, rho_accurate, bemst, emust, accur, header, rfldir,
                            rfldn, flup, dfdt, uavg, uu, albmed, trnmed)
    results = {
        "uu": uu,
        "flup": flup,
        "rfldn": rfldn,
        "rfldir": rfldir,
        "tau_test_arr": tau_test_arr,
        "phi_arr": phi_arr
    }
else:
    # Load saved results from Stamnes' DISORT
    results = np.load("Stamnes_results/1b_test.npz")

# %% [markdown]
# **Comparisons**

# %%
(
    diff_flux_up,
    ratio_flux_up,
    diff_flux_down_diffuse,
    ratio_flux_down_diffuse,
    diff_flux_down_direct,
    ratio_flux_down_direct,
    diff,
    diff_ratio,
) = _compare(results, mu_to_compare, reorder_mu, flux_up, flux_down, u)
# Out:
# Max pointwise differences
#
# Upward (diffuse) fluxes
# Difference = 9.584952906566135e-05
# Difference ratio = 0.9999999976708235
#
# Downward (diffuse) fluxes
# Difference = 9.584426869637198e-05
# Difference ratio = 0.9999999989310144
#
# Direct (downward) fluxes
# Difference = 2.1294565577534286e-07
# Difference ratio = 9.264798488614142e-08
#
# Intensities
#
# At tau = 0.0
# Max pointwise difference = 1.7622098989811263e-05
# At tau = 0.0
# Max pointwise difference ratio = 0.00011486989671821188

# %% [markdown]
# **Does the test pass?**

# %%
assert np.max(ratio_flux_up[diff_flux_up > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_diffuse[diff_flux_down_diffuse > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_direct[diff_flux_down_direct > 1e-3], initial=0) < 1e-3
assert np.max(diff_ratio[diff > 1e-3], initial=0) < 1e-2

'''np.savez_compressed (
    "Stamnes_results/1b_test",
    phi_arr=phi_arr,
    tau_test_arr=tau_test_arr,
    uu=uu,
    flup=flup,
    rfldn=rfldn,
    rfldir=rfldir,
)'''

print("The test passes")
# Out:
# The test passes

# %% [markdown]
# **Plots**

# %%
Nphi_plot = int((NQuad * pi) // 2) * 2 + 1
phi_arr_plot, full_weights_phi = PythonicDISORT.subroutines.Clenshaw_Curtis_quad(Nphi_plot)

MU_ARR, PHI_ARR = np.meshgrid(phi_arr_plot, mu_arr[:NQuad // 2])

# %%
plot = u(0, phi_arr_plot)[:NQuad // 2]

fig, ax = plt.subplots(figsize=(9, 6), subplot_kw={"projection": "polar"})

_cf = ax.contourf(MU_ARR, PHI_ARR, plot)
ax.plot(phi0, mu0, "o", color="red", label="Direct beam")

ax.set_rlim(1.0, 0.0)

ax.set_xlabel(r"$\phi$")
#ax.set_ylabel(r"$\mu$")
ax.text(1, 0.75, r"$\mu$", transform=ax.transAxes,
        rotation=0, ha="center", va="center")
fig.colorbar(_cf, ax=ax, pad=0.10)
ax.set_title("Upward intensity field at top of atmosphere")
ax.legend()
plt.show()

# %% [markdown]
# -------

# %% [markdown]
# # 1c

# %% [markdown]
# **PythonicDISORT**

# %%
######################################### PYDISORT ARGUMENTS #######################################

tau_arr = 0.03125
omega_arr = 0.99
NQuad = 16
Leg_coeffs_all = np.zeros(17)
Leg_coeffs_all[0] = 1
mu0 = 0.1
I0 = pi / mu0
phi0 = pi

# Optional (used)

# Optional (unused)
NLeg=None
NFourier=None
b_pos=0
b_neg=0
only_flux=False
f_arr=0
NT_cor=False
BDRF_Fourier_modes=[]
s_poly_coeffs=np.array([[]])
use_banded_solver_NLayers=10
autograd_compatible=False

####################################################################################################

# %%
# Call pydisort function
mu_arr, flux_up, flux_down, u0, u = PythonicDISORT.pydisort(
    tau_arr, omega_arr,
    NQuad,
    Leg_coeffs_all,
    mu0, I0, phi0,
)

# %% [markdown]
# **Stamnes' DISORT**

# %%
# tau test points
tau_test_arr = np.array([0, 0.03125])
Ntau = len(tau_test_arr)

# %%
# Stamnes' DISORT arguments
nlyr = 1
nmom = NQuad
nstr = NQuad
numu = NQuad
nphi = Nphi
ntau = Ntau
usrang = True
usrtau = True
ibcnd = 0
onlyfl = False
prnt = np.array([False, False, False, False, False])  # Prints to CMD instead of this notebook
plank = False
lamber = True
deltamplus = False
do_pseudo_sphere = False
dtauc = tau_arr
ssalb = omega_arr
pmom = Leg_coeffs_all.T
temper = np.zeros(nlyr + 1)
wvnmlo = 0
wvnmhi = 0
utau = tau_test_arr
umu0 = mu0
phi0 = phi0
umu = mu_arr_RO
phi = phi_arr
fbeam = I0
fisot = 0
albedo = 0
btemp = 0
ttemp = 0
temis = 0
earth_radius = 6371
h_lyr = np.zeros(nlyr + 1)
rhoq = np.zeros((nstr // 2, nstr + 1, nstr))
rhou = np.zeros((numu, nstr // 2 + 1, nstr))
rho_accurate = np.zeros((numu, nphi))
bemst = np.zeros(nstr // 2)
emust = np.zeros(numu)
accur = 0
header = ""
rfldir = np.zeros(ntau)
rfldn = np.zeros(ntau)
flup = np.zeros(ntau)
dfdt = np.zeros(ntau)
uavg = np.zeros(ntau)
uu = np.zeros((numu, ntau, nphi))
albmed = np.zeros(numu)
trnmed = np.zeros(numu)

# %%
if disort_is_installed:
    # Run disort, putting DFDT, UAVG, and UU in a, b, and c, respectively
    rfldir, rfldn, flup, dfdt, uavg, uu, albmed, trnmed = disort.disort(usrang, usrtau, ibcnd, onlyfl, prnt, plank, lamber, deltamplus, do_pseudo_sphere, dtauc, ssalb,
                            pmom, temper, wvnmlo, wvnmhi, utau, umu0, phi0 * 180/pi, umu, phi * 180/pi, fbeam, fisot, albedo, btemp, ttemp,
                            temis, earth_radius, h_lyr, rhoq, rhou, rho_accurate, bemst, emust, accur, header, rfldir,
                            rfldn, flup, dfdt, uavg, uu, albmed, trnmed)
    results = {
        "uu": uu,
        "flup": flup,
        "rfldn": rfldn,
        "rfldir": rfldir,
        "tau_test_arr": tau_test_arr,
        "phi_arr": phi_arr
    }
else:
    # Load saved results from Stamnes' DISORT
    results = np.load("Stamnes_results/1c_test.npz")

# %% [markdown]
# **Comparisons**

# %%
(
    diff_flux_up,
    ratio_flux_up,
    diff_flux_down_diffuse,
    ratio_flux_down_diffuse,
    diff_flux_down_direct,
    ratio_flux_down_direct,
    diff,
    diff_ratio,
) = _compare(results, mu_to_compare, reorder_mu, flux_up, flux_down, u)
# Out:
# Max pointwise differences
#
# Upward (diffuse) fluxes
# Difference = 3.599914459306852e-07
# Difference ratio = 0.9999999998740872
#
# Downward (diffuse) fluxes
# Difference = 4.951528310703779e-07
# Difference ratio = 1.1910545093172384e-06
#
# Direct (downward) fluxes
# Difference = 2.1294565577534286e-07
# Difference ratio = 9.264798488614142e-08
#
# Intensities
#
# At tau = 0.03125
# Max pointwise difference = 1.4695143769616337e-06
# At tau = 0.03125
# Max pointwise difference ratio = 2.4555015435940024e-06

# %% [markdown]
# **Does the test pass?**

# %%
assert np.max(ratio_flux_up[diff_flux_up > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_diffuse[diff_flux_down_diffuse > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_direct[diff_flux_down_direct > 1e-3], initial=0) < 1e-3
assert np.max(diff_ratio[diff > 1e-3], initial=0) < 1e-2

'''np.savez_compressed (
    "Stamnes_results/1c_test",
    phi_arr=phi_arr,
    tau_test_arr=tau_test_arr,
    uu=uu,
    flup=flup,
    rfldn=rfldn,
    rfldir=rfldir,
)'''

print("The test passes")
# Out:
# The test passes

# %% [markdown]
# **Plots**

# %%
Nphi_plot = int((NQuad * pi) // 2) * 2 + 1
phi_arr_plot, full_weights_phi = PythonicDISORT.subroutines.Clenshaw_Curtis_quad(Nphi_plot)

MU_ARR, PHI_ARR = np.meshgrid(phi_arr_plot, mu_arr[:NQuad // 2])

# %%
plot = u(0, phi_arr_plot)[:NQuad // 2]

fig, ax = plt.subplots(figsize=(9, 6), subplot_kw={"projection": "polar"})

_cf = ax.contourf(MU_ARR, PHI_ARR, plot)
ax.plot(phi0, mu0, "o", color="red", label="Direct beam")

ax.set_rlim(1.0, 0.0)

ax.set_xlabel(r"$\phi$")
#ax.set_ylabel(r"$\mu$")
ax.text(1, 0.75, r"$\mu$", transform=ax.transAxes,
        rotation=0, ha="center", va="center")
fig.colorbar(_cf, ax=ax, pad=0.10)
ax.set_title("Upward intensity field at top of atmosphere")
ax.legend()
plt.show()

# %% [markdown]
# -------

# %% [markdown]
# # 1d

# %% [markdown]
# **PythonicDISORT**

# %%
######################################### PYDISORT ARGUMENTS #######################################

tau_arr = 32
omega_arr = 0.2
NQuad = 16
Leg_coeffs_all = np.zeros(17)
Leg_coeffs_all[0] = 1
mu0 = 0.1
I0 = pi / mu0
phi0 = pi

# Optional (used)

# Optional (unused)
NLeg=None
NFourier=None
b_pos=0
b_neg=0
only_flux=False
f_arr=0
NT_cor=False
BDRF_Fourier_modes=[]
s_poly_coeffs=np.array([[]])
use_banded_solver_NLayers=10
autograd_compatible=False

####################################################################################################

# %%
# Call pydisort function
mu_arr, flux_up, flux_down, u0, u = PythonicDISORT.pydisort(
    tau_arr, omega_arr,
    NQuad,
    Leg_coeffs_all,
    mu0, I0, phi0,
)

# %% [markdown]
# **Stamnes' DISORT**

# %%
# tau test points
tau_test_arr = np.array([0, 32])
Ntau = len(tau_test_arr)

# %%
# Stamnes' DISORT arguments
nlyr = 1
nmom = NQuad
nstr = NQuad
numu = NQuad
nphi = Nphi
ntau = Ntau
usrang = True
usrtau = True
ibcnd = 0
onlyfl = False
prnt = np.array([False, False, False, False, False])  # Prints to CMD instead of this notebook
plank = False
lamber = True
deltamplus = False
do_pseudo_sphere = False
dtauc = tau_arr
ssalb = omega_arr
pmom = Leg_coeffs_all.T
temper = np.zeros(nlyr + 1)
wvnmlo = 0
wvnmhi = 0
utau = tau_test_arr
umu0 = mu0
phi0 = phi0
umu = mu_arr_RO
phi = phi_arr
fbeam = I0
fisot = 0
albedo = 0
btemp = 0
ttemp = 0
temis = 0
earth_radius = 6371
h_lyr = np.zeros(nlyr + 1)
rhoq = np.zeros((nstr // 2, nstr + 1, nstr))
rhou = np.zeros((numu, nstr // 2 + 1, nstr))
rho_accurate = np.zeros((numu, nphi))
bemst = np.zeros(nstr // 2)
emust = np.zeros(numu)
accur = 0
header = ""
rfldir = np.zeros(ntau)
rfldn = np.zeros(ntau)
flup = np.zeros(ntau)
dfdt = np.zeros(ntau)
uavg = np.zeros(ntau)
uu = np.zeros((numu, ntau, nphi))
albmed = np.zeros(numu)
trnmed = np.zeros(numu)

# %%
if disort_is_installed:
    # Run disort, putting DFDT, UAVG, and UU in a, b, and c, respectively
    rfldir, rfldn, flup, dfdt, uavg, uu, albmed, trnmed = disort.disort(usrang, usrtau, ibcnd, onlyfl, prnt, plank, lamber, deltamplus, do_pseudo_sphere, dtauc, ssalb,
                            pmom, temper, wvnmlo, wvnmhi, utau, umu0, phi0 * 180/pi, umu, phi * 180/pi, fbeam, fisot, albedo, btemp, ttemp,
                            temis, earth_radius, h_lyr, rhoq, rhou, rho_accurate, bemst, emust, accur, header, rfldir,
                            rfldn, flup, dfdt, uavg, uu, albmed, trnmed)
    results = {
        "uu": uu,
        "flup": flup,
        "rfldn": rfldn,
        "rfldir": rfldir,
        "tau_test_arr": tau_test_arr,
        "phi_arr": phi_arr
    }
else:
    # Load saved results from Stamnes' DISORT
    results = np.load("Stamnes_results/1d_test.npz")

# %% [markdown]
# **Comparisons**

# %%
(
    diff_flux_up,
    ratio_flux_up,
    diff_flux_down_diffuse,
    ratio_flux_down_diffuse,
    diff_flux_down_direct,
    ratio_flux_down_direct,
    diff,
    diff_ratio,
) = _compare(results, mu_to_compare, reorder_mu, flux_up, flux_down, u)
# Out:
# Max pointwise differences
#
# Upward (diffuse) fluxes
# Difference = 9.177695436957123e-09
# Difference ratio = 0.9999999735460621
#
# Downward (diffuse) fluxes
# Difference = 2.384185795375461e-07
# Difference ratio = 1.0000000018286477
#
# Direct (downward) fluxes
# Difference = 8.742278012618954e-08
# Difference ratio = 2.7827534417466256e-08
#
# Intensities
#
# At tau = 0
# Max pointwise difference = 2.227532669429877e-08
# At tau = 32
# Max pointwise difference ratio = 4.171987848815642e-06

# %% [markdown]
# **Does the test pass?**

# %%
assert np.max(ratio_flux_up[diff_flux_up > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_diffuse[diff_flux_down_diffuse > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_direct[diff_flux_down_direct > 1e-3], initial=0) < 1e-3
assert np.max(diff_ratio[diff > 1e-3], initial=0) < 1e-2

'''np.savez_compressed (
    "Stamnes_results/1d_test",
    phi_arr=phi_arr,
    tau_test_arr=tau_test_arr,
    uu=uu,
    flup=flup,
    rfldn=rfldn,
    rfldir=rfldir,
)'''

print("The test passes")
# Out:
# The test passes

# %% [markdown]
# **Plots**

# %%
Nphi_plot = int((NQuad * pi) // 2) * 2 + 1
phi_arr_plot, full_weights_phi = PythonicDISORT.subroutines.Clenshaw_Curtis_quad(Nphi_plot)

MU_ARR, PHI_ARR = np.meshgrid(phi_arr_plot, mu_arr[:NQuad // 2])

# %%
plot = u(0, phi_arr_plot)[:NQuad // 2]

fig, ax = plt.subplots(figsize=(9, 6), subplot_kw={"projection": "polar"})

_cf = ax.contourf(MU_ARR, PHI_ARR, plot)
ax.plot(phi0, mu0, "o", color="red", label="Direct beam")

ax.set_rlim(1.0, 0.0)

ax.set_xlabel(r"$\phi$")
#ax.set_ylabel(r"$\mu$")
ax.text(1, 0.75, r"$\mu$", transform=ax.transAxes,
        rotation=0, ha="center", va="center")
fig.colorbar(_cf, ax=ax, pad=0.10)
ax.set_title("Upward intensity field at top of atmosphere")
ax.legend()
plt.show()

# %% [markdown]
# -------

# %% [markdown]
# # 1e

# %% [markdown]
# **PythonicDISORT**

# %%
######################################### PYDISORT ARGUMENTS #######################################

tau_arr = 32
omega_arr = 1 - 1e-6  # Reduced from 1 (conservative scattering) which is not implemented
NQuad = 16
Leg_coeffs_all = np.zeros(17)
Leg_coeffs_all[0] = 1
mu0 = 0.1
I0 = pi / mu0
phi0 = pi

# Optional (used)

# Optional (unused)
NLeg=None
NFourier=None
b_pos=0
b_neg=0
only_flux=False
f_arr=0
NT_cor=False
BDRF_Fourier_modes=[]
s_poly_coeffs=np.array([[]])
use_banded_solver_NLayers=10
autograd_compatible=False

####################################################################################################

# %%
# Call pydisort function
mu_arr, flux_up, flux_down, u0, u = PythonicDISORT.pydisort(
    tau_arr, omega_arr,
    NQuad,
    Leg_coeffs_all,
    mu0, I0, phi0,
)

# %% [markdown]
# **Stamnes' DISORT**

# %%
# tau test points
tau_test_arr = np.array([0, 32])
Ntau = len(tau_test_arr)

# %%
# Stamnes' DISORT arguments
nlyr = 1
nmom = NQuad
nstr = NQuad
numu = NQuad
nphi = Nphi
ntau = Ntau
usrang = True
usrtau = True
ibcnd = 0
onlyfl = False
prnt = np.array([False, False, False, False, False])  # Prints to CMD instead of this notebook
plank = False
lamber = True
deltamplus = False
do_pseudo_sphere = False
dtauc = tau_arr
ssalb = omega_arr
pmom = Leg_coeffs_all.T
temper = np.zeros(nlyr + 1)
wvnmlo = 0
wvnmhi = 0
utau = tau_test_arr
umu0 = mu0
phi0 = phi0
umu = mu_arr_RO
phi = phi_arr
fbeam = I0
fisot = 0
albedo = 0
btemp = 0
ttemp = 0
temis = 0
earth_radius = 6371
h_lyr = np.zeros(nlyr + 1)
rhoq = np.zeros((nstr // 2, nstr + 1, nstr))
rhou = np.zeros((numu, nstr // 2 + 1, nstr))
rho_accurate = np.zeros((numu, nphi))
bemst = np.zeros(nstr // 2)
emust = np.zeros(numu)
accur = 0
header = ""
rfldir = np.zeros(ntau)
rfldn = np.zeros(ntau)
flup = np.zeros(ntau)
dfdt = np.zeros(ntau)
uavg = np.zeros(ntau)
uu = np.zeros((numu, ntau, nphi))
albmed = np.zeros(numu)
trnmed = np.zeros(numu)

# %%
if disort_is_installed:
    # Run disort, putting DFDT, UAVG, and UU in a, b, and c, respectively
    rfldir, rfldn, flup, dfdt, uavg, uu, albmed, trnmed = disort.disort(usrang, usrtau, ibcnd, onlyfl, prnt, plank, lamber, deltamplus, do_pseudo_sphere, dtauc, ssalb,
                            pmom, temper, wvnmlo, wvnmhi, utau, umu0, phi0 * 180/pi, umu, phi * 180/pi, fbeam, fisot, albedo, btemp, ttemp,
                            temis, earth_radius, h_lyr, rhoq, rhou, rho_accurate, bemst, emust, accur, header, rfldir,
                            rfldn, flup, dfdt, uavg, uu, albmed, trnmed)
    results = {
        "uu": uu,
        "flup": flup,
        "rfldn": rfldn,
        "rfldir": rfldir,
        "tau_test_arr": tau_test_arr,
        "phi_arr": phi_arr
    }
else:
    # Load saved results from Stamnes' DISORT
    results = np.load("Stamnes_results/1e_test.npz")

# %% [markdown]
# **Comparisons**

# %%
(
    diff_flux_up,
    ratio_flux_up,
    diff_flux_down_diffuse,
    ratio_flux_down_diffuse,
    diff_flux_down_direct,
    ratio_flux_down_direct,
    diff,
    diff_ratio,
) = _compare(results, mu_to_compare, reorder_mu, flux_up, flux_down, u)
# Out:
# Max pointwise differences
#
# Upward (diffuse) fluxes
# Difference = 5.570942778199139e-06
# Difference ratio = 1.81238609314545e-06
#
# Downward (diffuse) fluxes
# Difference = 1.4606280906714897e-06
# Difference ratio = 2.1588996274046077e-05
#
# Direct (downward) fluxes
# Difference = 8.742278012618954e-08
# Difference ratio = 2.7827534417466256e-08
#
# Intensities
#
# At tau = 0
# Max pointwise difference = 2.4804166147696094e-06
# At tau = 32
# Max pointwise difference ratio = 8.314951307198851e-05

# %% [markdown]
# **Does the test pass?**

# %%
assert np.max(ratio_flux_up[diff_flux_up > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_diffuse[diff_flux_down_diffuse > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_direct[diff_flux_down_direct > 1e-3], initial=0) < 1e-3
assert np.max(diff_ratio[diff > 1e-3], initial=0) < 1e-2

'''np.savez_compressed (
    "Stamnes_results/1e_test",
    phi_arr=phi_arr,
    tau_test_arr=tau_test_arr,
    uu=uu,
    flup=flup,
    rfldn=rfldn,
    rfldir=rfldir,
)
'''
print("The test passes")
# Out:
# The test passes

# %% [markdown]
# **Plots**

# %%
Nphi_plot = int((NQuad * pi) // 2) * 2 + 1
phi_arr_plot, full_weights_phi = PythonicDISORT.subroutines.Clenshaw_Curtis_quad(Nphi_plot)

MU_ARR, PHI_ARR = np.meshgrid(phi_arr_plot, mu_arr[:NQuad // 2])

# %%
plot = u(0, phi_arr_plot)[:NQuad // 2]

fig, ax = plt.subplots(figsize=(9, 6), subplot_kw={"projection": "polar"})

_cf = ax.contourf(MU_ARR, PHI_ARR, plot)
ax.plot(phi0, mu0, "o", color="red", label="Direct beam")

ax.set_rlim(1.0, 0.0)

ax.set_xlabel(r"$\phi$")
#ax.set_ylabel(r"$\mu$")
ax.text(1, 0.75, r"$\mu$", transform=ax.transAxes,
        rotation=0, ha="center", va="center")
fig.colorbar(_cf, ax=ax, pad=0.10)
ax.set_title("Upward intensity field at top of atmosphere")
ax.legend()
plt.show()

# %% [markdown]
# -------

# %% [markdown]
# # 1f

# %% [markdown]
# **PythonicDISORT**

# %%
######################################### PYDISORT ARGUMENTS #######################################

tau_arr = 32
omega_arr = 0.99
NQuad = 16
Leg_coeffs_all = np.zeros(17)
Leg_coeffs_all[0] = 1
mu0 = 0.1
I0 = pi / mu0
phi0 = pi

# Optional (used)

# Optional (unused)
NLeg=None
NFourier=None
b_pos=0
b_neg=0
only_flux=False
f_arr=0
NT_cor=False
BDRF_Fourier_modes=[]
s_poly_coeffs=np.array([[]])
use_banded_solver_NLayers=10
autograd_compatible=False

####################################################################################################

# %%
# Call pydisort function
mu_arr, flux_up, flux_down, u0, u = PythonicDISORT.pydisort(
    tau_arr, omega_arr,
    NQuad,
    Leg_coeffs_all,
    mu0, I0, phi0,
)

# %% [markdown]
# **Stamnes' DISORT**

# %%
# tau test points
tau_test_arr = np.array([0, 32])
Ntau = len(tau_test_arr)

# %%
# Stamnes' DISORT arguments
nlyr = 1
nmom = NQuad
nstr = NQuad
numu = NQuad
nphi = Nphi
ntau = Ntau
usrang = True
usrtau = True
ibcnd = 0
onlyfl = False
prnt = np.array([False, False, False, False, False])  # Prints to CMD instead of this notebook
plank = False
lamber = True
deltamplus = False
do_pseudo_sphere = False
dtauc = tau_arr
ssalb = omega_arr
pmom = Leg_coeffs_all.T
temper = np.zeros(nlyr + 1)
wvnmlo = 0
wvnmhi = 0
utau = tau_test_arr
umu0 = mu0
phi0 = phi0
umu = mu_arr_RO
phi = phi_arr
fbeam = I0
fisot = 0
albedo = 0
btemp = 0
ttemp = 0
temis = 0
earth_radius = 6371
h_lyr = np.zeros(nlyr + 1)
rhoq = np.zeros((nstr // 2, nstr + 1, nstr))
rhou = np.zeros((numu, nstr // 2 + 1, nstr))
rho_accurate = np.zeros((numu, nphi))
bemst = np.zeros(nstr // 2)
emust = np.zeros(numu)
accur = 0
header = ""
rfldir = np.zeros(ntau)
rfldn = np.zeros(ntau)
flup = np.zeros(ntau)
dfdt = np.zeros(ntau)
uavg = np.zeros(ntau)
uu = np.zeros((numu, ntau, nphi))
albmed = np.zeros(numu)
trnmed = np.zeros(numu)

# %%
if disort_is_installed:
    # Run disort, putting DFDT, UAVG, and UU in a, b, and c, respectively
    rfldir, rfldn, flup, dfdt, uavg, uu, albmed, trnmed = disort.disort(usrang, usrtau, ibcnd, onlyfl, prnt, plank, lamber, deltamplus, do_pseudo_sphere, dtauc, ssalb,
                            pmom, temper, wvnmlo, wvnmhi, utau, umu0, phi0 * 180/pi, umu, phi * 180/pi, fbeam, fisot, albedo, btemp, ttemp,
                            temis, earth_radius, h_lyr, rhoq, rhou, rho_accurate, bemst, emust, accur, header, rfldir,
                            rfldn, flup, dfdt, uavg, uu, albmed, trnmed)
    results = {
        "uu": uu,
        "flup": flup,
        "rfldn": rfldn,
        "rfldir": rfldir,
        "tau_test_arr": tau_test_arr,
        "phi_arr": phi_arr
    }
else:
    # Load saved results from Stamnes' DISORT
    results = np.load("Stamnes_results/1f_test.npz")

# %% [markdown]
# **Comparisons**

# %%
(
    diff_flux_up,
    ratio_flux_up,
    diff_flux_down_diffuse,
    ratio_flux_down_diffuse,
    diff_flux_down_direct,
    ratio_flux_down_direct,
    diff,
    diff_ratio,
) = _compare(results, mu_to_compare, reorder_mu, flux_up, flux_down, u)
# Out:
# Max pointwise differences
#
# Upward (diffuse) fluxes
# Difference = 4.2272286249200874e-07
# Difference ratio = 1.533393451296101e-07
#
# Downward (diffuse) fluxes
# Difference = 2.384185799735296e-07
# Difference ratio = 1.0000000036572951
#
# Direct (downward) fluxes
# Difference = 8.742278012618954e-08
# Difference ratio = 2.7827534417466256e-08
#
# Intensities
#
# At tau = 0
# Max pointwise difference = 5.523037964749733e-07
# At tau = 32
# Max pointwise difference ratio = 9.106947073856648e-06

# %% [markdown]
# **Does the test pass?**

# %%
assert np.max(ratio_flux_up[diff_flux_up > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_diffuse[diff_flux_down_diffuse > 1e-3], initial=0) < 1e-3
assert np.max(ratio_flux_down_direct[diff_flux_down_direct > 1e-3], initial=0) < 1e-3
assert np.max(diff_ratio[diff > 1e-3], initial=0) < 1e-2

'''np.savez_compressed (
    "Stamnes_results/1f_test",
    phi_arr=phi_arr,
    tau_test_arr=tau_test_arr,
    uu=uu,
    flup=flup,
    rfldn=rfldn,
    rfldir=rfldir,
)'''

print("The test passes")
# Out:
# The test passes

# %% [markdown]
# **Plots**

# %%
Nphi_plot = int((NQuad * pi) // 2) * 2 + 1
phi_arr_plot, full_weights_phi = PythonicDISORT.subroutines.Clenshaw_Curtis_quad(Nphi_plot)

MU_ARR, PHI_ARR = np.meshgrid(phi_arr_plot, mu_arr[:NQuad // 2])

# %%
plot = u(0, phi_arr_plot)[:NQuad // 2]

fig, ax = plt.subplots(figsize=(9, 6), subplot_kw={"projection": "polar"})

_cf = ax.contourf(MU_ARR, PHI_ARR, plot)
ax.plot(phi0, mu0, "o", color="red", label="Direct beam")

ax.set_rlim(1.0, 0.0)

ax.set_xlabel(r"$\phi$")
#ax.set_ylabel(r"$\mu$")
ax.text(1, 0.75, r"$\mu$", transform=ax.transAxes,
        rotation=0, ha="center", va="center")
fig.colorbar(_cf, ax=ax, pad=0.10)
ax.set_title("Upward intensity field at top of atmosphere")
ax.legend()
plt.show()

# %% [markdown]
# -------
